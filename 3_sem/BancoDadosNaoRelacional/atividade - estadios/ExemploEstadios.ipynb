# %%
import numpy as np
import pandas as pd
import json
import folium

# !python -m pip install pymongo
from pymongo import MongoClient
# Out:
# Collecting pymongo
#   Downloading pymongo-4.6.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (677 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 677.1/677.1 kB 5.1 MB/s eta 0:00:00
# Collecting dnspython<3.0.0,>=1.16.0 (from pymongo)
#   Downloading dnspython-2.4.2-py3-none-any.whl (300 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 300.4/300.4 kB 7.1 MB/s eta 0:00:00
# Installing collected packages: dnspython, pymongo
# Successfully installed dnspython-2.4.2 pymongo-4.6.0

# %%
dataset = "https://raw.githubusercontent.com/ProfAndersonVanin/FATEC_Banco_de_Dados_NoSQL/main/material%20de%20apoio/base%20de%20dados/Coordenadas%20csv.csv"

# %%
estadios_df = pd.read_csv(dataset)

# %%
estadios_df.head(5)
# Out:
#              nome  capacidade  latitude  longitude
# 0        Maracanã       78838 -22.90981  -43.23391
# 1  Mané Garrincha       72000 -15.78375  -47.89903
# 2         Morumbi       66795 -23.60006  -46.72016
# 3  Arena Castelão       63903  -3.80674  -38.52168
# 4        Mineirão       61927 -19.86591  -43.97104

# %%
dicionario = estadios_df.to_dict('records')

# %%
dicionario
# Out:
# [{'nome': 'Maracanã',
#   'capacidade': 78838,
#   'latitude': -22.90981,
#   'longitude': -43.23391},
#  {'nome': 'Mané Garrincha',
#   'capacidade': 72000,
#   'latitude': -15.78375,
#   'longitude': -47.89903},
#  {'nome': 'Morumbi',
#   'capacidade': 66795,
#   'latitude': -23.60006,
#   'longitude': -46.72016},
#  {'nome': 'Arena Castelão',
#   'capacidade': 63903,
#   'latitude': -3.80674,
#   'longitude': -38.52168},
#  {'nome': 'Mineirão',
#   'capacidade': 61927,
#   'latitude': -19.86591,
#   'longitude': -43.97104},
#  {'nome': 'Arruda',
#   'capacidade': 60000,
#   'latitude': -8.02681,
#   'longitude': -34.8912},
#  {'nome': 'Arena do Grêmio',
#   'capacidade': 55662,
#   'latitude': -29.97404,
#   'longitude': -51.19511},
#  {'nome': 'Mangueirão',
#   'capacidade': 55645,
#   'latitude': -1.38114,
#   'longitude': -48.44483},
#  {'nome': 'Beira-Rio',
#   'capacidade': 50848,
#   'latitude': -30.06549,
#   'longitude': -51.23492},
#  {'nome': 'Neo Química Arena',
#   'capacidade': 48234,
#   'latitude': -23.54529,
#   'longitude': -46.47429},
#  {'nome': 'Arena Fonte Nova',
#   'capacidade': 48000,
#   'latitude': -12.97889,
#   'longitude': -38.50348},
#  {'nome': 'Parque do Sabiá',
#   'capacidade': 46782,
#   'latitude': -18.91309,
#   'longitude': -48.23299},
#  {'nome': 'Arena Pernambuco',
#   'capacidade': 46000,
#   'latitude': -8.02681,
#   'longitude': -34.8912},
#  {'nome': 'Arena MRV',
#   'capacidade': 46000,
#   'latitude': -19.93001,
#   'longitude': -44.01388},
#  {'nome': 'Prudentão',
#   'capacidade': 45954,
#   'latitude': -22.09857,
#   'longitude': -51.41506},
#  {'nome': 'Engenhão',
#   'capacidade': 45217,
#   'latitude': -22.89319,
#   'longitude': -43.29357},
#  {'nome': 'Albertão',
#   'capacidade': 44200,
#   'latitude': -5.11614,
#   'longitude': -42.79287},
#  {'nome': 'Morenão',
#   'capacidade': 44200,
#   'latitude': -20.50143,
#   'longitude': -54.61022},
#  {'nome': 'Arena Pantanal',
#   'capacidade': 44097,
#   'latitude': -15.60406,
#   'longitude': -56.1223},
#  {'nome': 'Arena da Amazônia',
#   'capacidade': 44000,
#   'latitude': -3.08434,
#   'longitude': -60.0265}]

# %%
cliente =MongoClient("mongodb+srv://giovannavillanovagi:<password>@clusterestadios.kimsf4z.mongodb.net/?retryWrites=true&w=majority")

# %%
db = cliente.get_database('futebol')

# %%
db.estadios.insert_many(dicionario)
# Out:
# InsertManyResult([ObjectId('65566bc20eb5c9a3d677f186'), ObjectId('65566bc20eb5c9a3d677f187'), ObjectId('65566bc20eb5c9a3d677f188'), ObjectId('65566bc20eb5c9a3d677f189'), ObjectId('65566bc20eb5c9a3d677f18a'), ObjectId('65566bc20eb5c9a3d677f18b'), ObjectId('65566bc20eb5c9a3d677f18c'), ObjectId('65566bc20eb5c9a3d677f18d'), ObjectId('65566bc20eb5c9a3d677f18e'), ObjectId('65566bc20eb5c9a3d677f18f'), ObjectId('65566bc20eb5c9a3d677f190'), ObjectId('65566bc20eb5c9a3d677f191'), ObjectId('65566bc20eb5c9a3d677f192'), ObjectId('65566bc20eb5c9a3d677f193'), ObjectId('65566bc20eb5c9a3d677f194'), ObjectId('65566bc20eb5c9a3d677f195'), ObjectId('65566bc20eb5c9a3d677f196'), ObjectId('65566bc20eb5c9a3d677f197'), ObjectId('65566bc20eb5c9a3d677f198'), ObjectId('65566bc20eb5c9a3d677f199')], acknowledged=True)

# %%
estadios = db.estadios

# %%
estadios
# Out:
# Collection(Database(MongoClient(host=['ac-vsh9mq2-shard-00-00.kimsf4z.mongodb.net:27017', 'ac-vsh9mq2-shard-00-02.kimsf4z.mongodb.net:27017', 'ac-vsh9mq2-shard-00-01.kimsf4z.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', authsource='admin', replicaset='atlas-d0jz65-shard-0', tls=True), 'futebol'), 'estadios')

# %%
list(estadios.find())
# Out:
# [{'_id': ObjectId('65566b9493c523e9b59aa78c'),
#   'nome': 'Vila Belmiro',
#   'capacidade': 21732,
#   'latitude': -23.57243,
#   'longitude': -46.20123},
#  {'_id': ObjectId('65566bc20eb5c9a3d677f186'),
#   'nome': 'Maracanã',
#   'capacidade': 78838,
#   'latitude': -22.90981,
#   'longitude': -43.23391},
#  {'_id': ObjectId('65566bc20eb5c9a3d677f187'),
#   'nome': 'Mané Garrincha',
#   'capacidade': 72000,
#   'latitude': -15.78375,
#   'longitude': -47.89903},
#  {'_id': ObjectId('65566bc20eb5c9a3d677f188'),
#   'nome': 'Morumbi',
#   'capacidade': 66795,
#   'latitude': -23.60006,
#   'longitude': -46.72016},
#  {'_id': ObjectId('65566bc20eb5c9a3d677f189'),
#   'nome': 'Arena Castelão',
#   'capacidade': 63903,
#   'latitude': -3.80674,
#   'longitude': -38.52168},
#  {'_id': ObjectId('65566bc20eb5c9a3d677f18a'),
#   'nome': 'Mineirão',
#   'capacidade': 61927,
#   'latitude': -19.86591,
#   'longitude': -43.97104},
#  {'_id': ObjectId('65566bc20eb5c9a3d677f18b'),
#   'nome': 'Arruda',
#   'capacidade': 60000,
#   'latitude': -8.02681,
#   'longitude': -34.8912},
#  {'_id': ObjectId('65566bc20eb5c9a3d677f18c'),
#   'nome': 'Arena do Grêmio',
#   'capacidade': 55662,
#   'latitude': -29.97404,
#   'longitude': -51.19511},
#  {'_id': ObjectId('65566bc20eb5c9a3d677f18d'),
#   'nome': 'Mangueirão',
#   'capacidade': 55645,
#   'latitude': -1.38114,
#   'longitude': -48.44483},
#  {'_id': ObjectId('65566bc20eb5c9a3d677f18e'),
#   'nome': 'Beira-Rio',
#   'capacidade': 50848,
#   'latitude': -30.06549,
#   'longitude': -51.23492},
#  {'_id': ObjectId('65566bc20eb5c9a3d677f18f'),
#   'nome': 'Neo Química Arena',
#   'capacidade': 48234,
#   'latitude': -23.54529,
#   'longitude': -46.47429},
#  {'_id': ObjectId('65566bc20eb5c9a3d677f190'),
#   'nome': 'Arena Fonte Nova',
#   'capacidade': 48000,
#   'latitude': -12.97889,
#   'longitude': -38.50348},
#  {'_id': ObjectId('65566bc20eb5c9a3d677f191'),
#   'nome': 'Parque do Sabiá',
#   'capacidade': 46782,
#   'latitude': -18.91309,
#   'longitude': -48.23299},
#  {'_id': ObjectId('65566bc20eb5c9a3d677f192'),
#   'nome': 'Arena Pernambuco',
#   'capacidade': 46000,
#   'latitude': -8.02681,
#   'longitude': -34.8912},
#  {'_id': ObjectId('65566bc20eb5c9a3d677f193'),
#   'nome': 'Arena MRV',
#   'capacidade': 46000,
#   'latitude': -19.93001,
#   'longitude': -44.01388},
#  {'_id': ObjectId('65566bc20eb5c9a3d677f194'),
#   'nome': 'Prudentão',
#   'capacidade': 45954,
#   'latitude': -22.09857,
#   'longitude': -51.41506},
#  {'_id': ObjectId('65566bc20eb5c9a3d677f195'),
#   'nome': 'Engenhão',
#   'capacidade': 45217,
#   'latitude': -22.89319,
#   'longitude': -43.29357},
#  {'_id': ObjectId('65566bc20eb5c9a3d677f196'),
#   'nome': 'Albertão',
#   'capacidade': 44200,
#   'latitude': -5.11614,
#   'longitude': -42.79287},
#  {'_id': ObjectId('65566bc20eb5c9a3d677f197'),
#   'nome': 'Morenão',
#   'capacidade': 44200,
#   'latitude': -20.50143,
#   'longitude': -54.61022},
#  {'_id': ObjectId('65566bc20eb5c9a3d677f198'),
#   'nome': 'Arena Pantanal',
#   'capacidade': 44097,
#   'latitude': -15.60406,
#   'longitude': -56.1223},
#  {'_id': ObjectId('65566bc20eb5c9a3d677f199'),
#   'nome': 'Arena da Amazônia',
#   'capacidade': 44000,
#   'latitude': -3.08434,
#   'longitude': -60.0265}]

# %%
center_lat =-14.24007
center_lon = -53.18050

# %%
consulta = list(estadios.find())

# %%
df_convertido = pd.DataFrame(consulta)

# %%
df_convertido.iloc[0]
# Out:
# _id           65566b9493c523e9b59aa78c
# nome                      Vila Belmiro
# capacidade                       21732
# latitude                     -23.57243
# longitude                    -46.20123
# Name: 0, dtype: object

# %%
locationmap = folium.Map(location=[ center_lat , center_lon ], zoom_start=5, width=800, height=600 )

# %%
qtde = len(df_convertido)

# %%
qtde
# Out:
# 21

# %%
for i in range(qtde):
    lng = float(df_convertido.iloc[i]['longitude'])
    lat = float(df_convertido.iloc[i]['latitude'])
    description = 'Estádio: ' +str(df_convertido.iloc[i]['nome'])+ '<br> Capacidade: ' +str(df_convertido.iloc[i]['capacidade'])
    folium.Marker( [ lat , lng ],
                  popup=description,
                   icon=folium.Icon(color='red')).add_to(locationmap)

# %%
locationmap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b7167ab921cd5e85cbf581ad22b613cc {
#                     position: relative;
#                     width: 800.0px;
#                     height: 600.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b7167ab921cd5e85cbf581ad22b613cc&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b7167ab921cd5e85cbf581ad22b613cc = L.map(
#                 &quot;map_b7167ab921cd5e85cbf581ad22b613cc&quot;,
#                 {
#                     center: [-14.24007, -53.1805],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cac55f298074cd653454ebfe4fb576d4 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_b7167ab921cd5e85cbf581ad22b613cc);
#
#
#             var marker_7007e703f890b011c3da345ee6d1f63b = L.marker(
#                 [-23.57243, -46.20123],
#                 {}
#             ).addTo(map_b7167ab921cd5e85cbf581ad22b613cc);
#
#
#             var icon_a3a1acbe0fa19d97920c2d53f3a789e3 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_7007e703f890b011c3da345ee6d1f63b.setIcon(icon_a3a1acbe0fa19d97920c2d53f3a789e3);
#
#
#         var popup_b87ff11abcfc4c8467abe9487ebffde5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a158bbde0bc2603161026fd86ae68a91 = $(`&lt;div id=&quot;html_a158bbde0bc2603161026fd86ae68a91&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Estádio: Vila Belmiro&lt;br&gt; Capacidade: 21732&lt;/div&gt;`)[0];
#                 popup_b87ff11abcfc4c8467abe9487ebffde5.setContent(html_a158bbde0bc2603161026fd86ae68a91);
#
#
#
#         marker_7007e703f890b011c3da345ee6d1f63b.bindPopup(popup_b87ff11abcfc4c8467abe9487ebffde5)
#         ;
#
#
#
#
#             var marker_0095f45756cf3656aa8317197f058f93 = L.marker(
#                 [-22.90981, -43.23391],
#                 {}
#             ).addTo(map_b7167ab921cd5e85cbf581ad22b613cc);
#
#
#             var icon_6ae1848e672a75422e7d38c3d4a1fb35 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_0095f45756cf3656aa8317197f058f93.setIcon(icon_6ae1848e672a75422e7d38c3d4a1fb35);
#
#
#         var popup_c4188ec9886f13a808171bc8e5a7c3f1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1aaed716881cb1752d509f812517ed64 = $(`&lt;div id=&quot;html_1aaed716881cb1752d509f812517ed64&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Estádio: Maracanã&lt;br&gt; Capacidade: 78838&lt;/div&gt;`)[0];
#                 popup_c4188ec9886f13a808171bc8e5a7c3f1.setContent(html_1aaed716881cb1752d509f812517ed64);
#
#
#
#         marker_0095f45756cf3656aa8317197f058f93.bindPopup(popup_c4188ec9886f13a808171bc8e5a7c3f1)
#         ;
#
#
#
#
#             var marker_ff0633adc35068e76a34a5fcf0119f19 = L.marker(
#                 [-15.78375, -47.89903],
#                 {}
#             ).addTo(map_b7167ab921cd5e85cbf581ad22b613cc);
#
#
#             var icon_71aecaa741aa8c03628bc01228ddb2bd = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_ff0633adc35068e76a34a5fcf0119f19.setIcon(icon_71aecaa741aa8c03628bc01228ddb2bd);
#
#
#         var popup_64ea050bdc7293d4b2e8c35497978c3c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_32400c7226ffb1a844e7c0c0fabc8240 = $(`&lt;div id=&quot;html_32400c7226ffb1a844e7c0c0fabc8240&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Estádio: Mané Garrincha&lt;br&gt; Capacidade: 72000&lt;/div&gt;`)[0];
#                 popup_64ea050bdc7293d4b2e8c35497978c3c.setContent(html_32400c7226ffb1a844e7c0c0fabc8240);
#
#
#
#         marker_ff0633adc35068e76a34a5fcf0119f19.bindPopup(popup_64ea050bdc7293d4b2e8c35497978c3c)
#         ;
#
#
#
#
#             var marker_4776eb0b88bec90d66ffaefcc35fe412 = L.marker(
#                 [-23.60006, -46.72016],
#                 {}
#             ).addTo(map_b7167ab921cd5e85cbf581ad22b613cc);
#
#
#             var icon_0b245bec8eea185016a7389721afb421 = L.AwesomeMarke
