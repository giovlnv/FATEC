# %%
import numpy as np
import pandas as pd
import json
import folium

# !python -m pip install pymongo
from pymongo import MongoClient
# Out:
# Collecting pymongo
#   Downloading pymongo-4.6.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (677 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 677.1/677.1 kB 7.1 MB/s eta 0:00:00
# Collecting dnspython<3.0.0,>=1.16.0 (from pymongo)
#   Downloading dnspython-2.4.2-py3-none-any.whl (300 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 300.4/300.4 kB 26.0 MB/s eta 0:00:00
# Installing collected packages: dnspython, pymongo
# Successfully installed dnspython-2.4.2 pymongo-4.6.0

# %%
dataset = "https://raw.githubusercontent.com/giovlnv/FATEC/master/3_sem/BancoDadosNaoRelacional/P2/PontosTuristicos.csv"

# %%
pontos_df = pd.read_csv(dataset)

# %%
pontos_df.head(5)
# Out:
#            Cidade                                          Descrição  \
# 0      Ouro Preto  Cidade histórica com arquitetura colonial e di...
# 1  Belo Horizonte  Capital de Minas Gerais, com museus, parques e...
# 2         Mariana  Cidade próxima a Ouro Preto, também com arquit...
# 3      Tiradentes  Preserva a arquitetura colonial e é famosa por...
# 4      Diamantina  Cidade histórica com casarões coloniais e pais...
#
#   Quantidade de Pontos Turísticos  Latitude  Longitude
# 0                             20+  -20.3796   -43.5122
# 1                             10+  -19.9190   -43.9386
# 2                             10+  -20.3778   -43.4140
# 3                             10+  -21.1106   -44.1736
# 4                             10+  -18.2448   -43.6000

# %%
dicionario = pontos_df.to_dict('records')

# %%
dicionario
# Out:
# [{'Cidade': 'Ouro Preto',
#   'Descrição': 'Cidade histórica com arquitetura colonial e diversas igrejas barrocas.',
#   'Quantidade de Pontos Turísticos': '20+',
#   'Latitude': -20.3796,
#   'Longitude': -43.5122},
#  {'Cidade': 'Belo Horizonte',
#   'Descrição': 'Capital de Minas Gerais, com museus, parques e arquitetura moderna.',
#   'Quantidade de Pontos Turísticos': '10+',
#   'Latitude': -19.919,
#   'Longitude': -43.9386},
#  {'Cidade': 'Mariana',
#   'Descrição': 'Cidade próxima a Ouro Preto, também com arquitetura colonial e museus.',
#   'Quantidade de Pontos Turísticos': '10+',
#   'Latitude': -20.3778,
#   'Longitude': -43.414},
#  {'Cidade': 'Tiradentes',
#   'Descrição': 'Preserva a arquitetura colonial e é famosa por eventos culturais.',
#   'Quantidade de Pontos Turísticos': '10+',
#   'Latitude': -21.1106,
#   'Longitude': -44.1736},
#  {'Cidade': 'Diamantina',
#   'Descrição': 'Cidade histórica com casarões coloniais e paisagens serranas.',
#   'Quantidade de Pontos Turísticos': '10+',
#   'Latitude': -18.2448,
#   'Longitude': -43.6},
#  {'Cidade': 'São João del-Rei',
#   'Descrição': 'Conserva o estilo colonial e é conhecida por suas festas tradicionais.',
#   'Quantidade de Pontos Turísticos': '10+',
#   'Latitude': -21.1314,
#   'Longitude': -44.2522},
#  {'Cidade': 'Sabará',
#   'Descrição': 'Cidade histórica próxima a Belo Horizonte, com igrejas e museus.',
#   'Quantidade de Pontos Turísticos': '10+',
#   'Latitude': -19.8912,
#   'Longitude': -43.8269},
#  {'Cidade': 'Congonhas',
#   'Descrição': 'Famosa pelas estátuas de Aleijadinho e igrejas barrocas.',
#   'Quantidade de Pontos Turísticos': '10+',
#   'Latitude': -20.5044,
#   'Longitude': -43.8583},
#  {'Cidade': 'Conselheiro Lafaiete',
#   'Descrição': 'Oferece atrações históricas e naturais nas proximidades.',
#   'Quantidade de Pontos Turísticos': '10+',
#   'Latitude': -20.6605,
#   'Longitude': -43.7849},
#  {'Cidade': 'Sabará',
#   'Descrição': 'Cidade histórica próxima a Belo Horizonte, com igrejas e museus.',
#   'Quantidade de Pontos Turísticos': '10+',
#   'Latitude': -19.8912,
#   'Longitude': -43.8269},
#  {'Cidade': 'Juiz de Fora',
#   'Descrição': 'Importante centro cultural e universitário, com arquitetura histórica.',
#   'Quantidade de Pontos Turísticos': '10+',
#   'Latitude': -21.7591,
#   'Longitude': -43.3392},
#  {'Cidade': 'Poços de Caldas',
#   'Descrição': 'Estância hidromineral com belezas naturais, parques e atrações turísticas.',
#   'Quantidade de Pontos Turísticos': '10+',
#   'Latitude': -21.7892,
#   'Longitude': -46.5673},
#  {'Cidade': 'Montes Claros',
#   'Descrição': 'Destaque regional, com praças, igrejas e eventos culturais.',
#   'Quantidade de Pontos Turísticos': '10+',
#   'Latitude': -16.7272,
#   'Longitude': -43.8697},
#  {'Cidade': 'Governador Valadares',
#   'Descrição': 'Conhecida pela prática de esportes radicais e eventos culturais.',
#   'Quantidade de Pontos Turísticos': '10+',
#   'Latitude': -18.8542,
#   'Longitude': -41.9568},
#  {'Cidade': 'Uberlândia',
#   'Descrição': 'Importante polo econômico e cultural, com parques e eventos.',
#   'Quantidade de Pontos Turísticos': '10+',
#   'Latitude': -18.9136,
#   'Longitude': -48.275},
#  {'Cidade': 'São Thomé das Letras',
#   'Descrição': 'Cidade mística com paisagens naturais e lendas locais.',
#   'Quantidade de Pontos Turísticos': '10+',
#   'Latitude': -21.7215,
#   'Longitude': -44.9825},
#  {'Cidade': 'Sete Lagoas',
#   'Descrição': 'Oferece atrações históricas, parques e uma barragem imponente.',
#   'Quantidade de Pontos Turísticos': '10+',
#   'Latitude': -19.4656,
#   'Longitude': -44.2469},
#  {'Cidade': 'Nova Lima',
#   'Descrição': 'Próxima a Belo Horizonte, conhecida por suas paisagens e mineração.',
#   'Quantidade de Pontos Turísticos': '10+',
#   'Latitude': -19.9846,
#   'Longitude': -43.8506},
#  {'Cidade': 'Lavras',
#   'Descrição': 'Importante centro universitário, com praças e patrimônio histórico.',
#   'Quantidade de Pontos Turísticos': '10+',
#   'Latitude': -21.2425,
#   'Longitude': -45.0002},
#  {'Cidade': 'Patos de Minas',
#   'Descrição': 'Destaque regional, com eventos culturais e paisagens naturais.',
#   'Quantidade de Pontos Turísticos': '10+',
#   'Latitude': -18.5766,
#   'Longitude': -46.5193}]

# %%
cliente = MongoClient("mongodb+srv://giovannavillanovagi:VWsh5OrqlOUuizct@clusterpontos.pis8bwd.mongodb.net/?retryWrites=true&w=majority")

# %%
db = cliente.get_database('pontos_turisticos')

# %%
db.minas_gerais.insert_many(dicionario)
# Out:
# InsertManyResult([ObjectId('65567f28c38f4a4b71f9f3cc'), ObjectId('65567f28c38f4a4b71f9f3cd'), ObjectId('65567f28c38f4a4b71f9f3ce'), ObjectId('65567f28c38f4a4b71f9f3cf'), ObjectId('65567f28c38f4a4b71f9f3d0'), ObjectId('65567f28c38f4a4b71f9f3d1'), ObjectId('65567f28c38f4a4b71f9f3d2'), ObjectId('65567f28c38f4a4b71f9f3d3'), ObjectId('65567f28c38f4a4b71f9f3d4'), ObjectId('65567f28c38f4a4b71f9f3d5'), ObjectId('65567f28c38f4a4b71f9f3d6'), ObjectId('65567f28c38f4a4b71f9f3d7'), ObjectId('65567f28c38f4a4b71f9f3d8'), ObjectId('65567f28c38f4a4b71f9f3d9'), ObjectId('65567f28c38f4a4b71f9f3da'), ObjectId('65567f28c38f4a4b71f9f3db'), ObjectId('65567f28c38f4a4b71f9f3dc'), ObjectId('65567f28c38f4a4b71f9f3dd'), ObjectId('65567f28c38f4a4b71f9f3de'), ObjectId('65567f28c38f4a4b71f9f3df')], acknowledged=True)

# %%
pontosTur = db.minas_gerais

# %%
pontosTur
# Out:
# Collection(Database(MongoClient(host=['ac-kqldptj-shard-00-01.pis8bwd.mongodb.net:27017', 'ac-kqldptj-shard-00-02.pis8bwd.mongodb.net:27017', 'ac-kqldptj-shard-00-00.pis8bwd.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', authsource='admin', replicaset='atlas-4yro7m-shard-0', tls=True), 'pontos_turisticos'), 'minas_gerais')

# %%
list(pontosTur.find())
# Out:
# [{'_id': ObjectId('65567f28c38f4a4b71f9f3cc'),
#   'Cidade': 'Ouro Preto',
#   'Descrição': 'Cidade histórica com arquitetura colonial e diversas igrejas barrocas.',
#   'Quantidade de Pontos Turísticos': '20+',
#   'Latitude': -20.3796,
#   'Longitude': -43.5122},
#  {'_id': ObjectId('65567f28c38f4a4b71f9f3cd'),
#   'Cidade': 'Belo Horizonte',
#   'Descrição': 'Capital de Minas Gerais, com museus, parques e arquitetura moderna.',
#   'Quantidade de Pontos Turísticos': '10+',
#   'Latitude': -19.919,
#   'Longitude': -43.9386},
#  {'_id': ObjectId('65567f28c38f4a4b71f9f3ce'),
#   'Cidade': 'Mariana',
#   'Descrição': 'Cidade próxima a Ouro Preto, também com arquitetura colonial e museus.',
#   'Quantidade de Pontos Turísticos': '10+',
#   'Latitude': -20.3778,
#   'Longitude': -43.414},
#  {'_id': ObjectId('65567f28c38f4a4b71f9f3cf'),
#   'Cidade': 'Tiradentes',
#   'Descrição': 'Preserva a arquitetura colonial e é famosa por eventos culturais.',
#   'Quantidade de Pontos Turísticos': '10+',
#   'Latitude': -21.1106,
#   'Longitude': -44.1736},
#  {'_id': ObjectId('65567f28c38f4a4b71f9f3d0'),
#   'Cidade': 'Diamantina',
#   'Descrição': 'Cidade histórica com casarões coloniais e paisagens serranas.',
#   'Quantidade de Pontos Turísticos': '10+',
#   'Latitude': -18.2448,
#   'Longitude': -43.6},
#  {'_id': ObjectId('65567f28c38f4a4b71f9f3d1'),
#   'Cidade': 'São João del-Rei',
#   'Descrição': 'Conserva o estilo colonial e é conhecida por suas festas tradicionais.',
#   'Quantidade de Pontos Turísticos': '10+',
#   'Latitude': -21.1314,
#   'Longitude': -44.2522},
#  {'_id': ObjectId('65567f28c38f4a4b71f9f3d2'),
#   'Cidade': 'Sabará',
#   'Descrição': 'Cidade histórica próxima a Belo Horizonte, com igrejas e museus.',
#   'Quantidade de Pontos Turísticos': '10+',
#   'Latitude': -19.8912,
#   'Longitude': -43.8269},
#  {'_id': ObjectId('65567f28c38f4a4b71f9f3d3'),
#   'Cidade': 'Congonhas',
#   'Descrição': 'Famosa pelas estátuas de Aleijadinho e igrejas barrocas.',
#   'Quantidade de Pontos Turísticos': '10+',
#   'Latitude': -20.5044,
#   'Longitude': -43.8583},
#  {'_id': ObjectId('65567f28c38f4a4b71f9f3d4'),
#   'Cidade': 'Conselheiro Lafaiete',
#   'Descrição': 'Oferece atrações históricas e naturais nas proximidades.',
#   'Quantidade de Pontos Turísticos': '10+',
#   'Latitude': -20.6605,
#   'Longitude': -43.7849},
#  {'_id': ObjectId('65567f28c38f4a4b71f9f3d5'),
#   'Cidade': 'Sabará',
#   'Descrição': 'Cidade histórica próxima a Belo Horizonte, com igrejas e museus.',
#   'Quantidade de Pontos Turísticos': '10+',
#   'Latitude': -19.8912,
#   'Longitude': -43.8269},
#  {'_id': ObjectId('65567f28c38f4a4b71f9f3d6'),
#   'Cidade': 'Juiz de Fora',
#   'Descrição': 'Importante centro cultural e universitário, com arquitetura histórica.',
#   'Quantidade de Pontos Turísticos': '10+',
#   'Latitude': -21.7591,
#   'Longitude': -43.3392},
#  {'_id': ObjectId('65567f28c38f4a4b71f9f3d7'),
#   'Cidade': 'Poços de Caldas',
#   'Descrição': 'Estância hidromineral com belezas naturais, parques e atrações turísticas.',
#   'Quantidade de Pontos Turísticos': '10+',
#   'Latitude': -21.7892,
#   'Longitude': -46.5673},
#  {'_id': ObjectId('65567f28c38f4a4b71f9f3d8'),
#   'Cidade': 'Montes Claros',
#   'Descrição': 'Destaque regional, com praças, igrejas e eventos culturais.',
#   'Quantidade de Pontos Turísticos': '10+',
#   'Latitude': -16.7272,
#   'Longitude': -43.8697},
#  {'_id': ObjectId('65567f28c38f4a4b71f9f3d9'),
#   'Cidade': 'Governador Valadares',
#   'Descrição': 'Conhecida pela prática de esportes radicais e eventos culturais.',
#   'Quantidade de Pontos Turísticos': '10+',
#   'Latitude': -18.8542,
#   'Longitude': -41.9568},
#  {'_id': ObjectId('65567f28c38f4a4b71f9f3da'),
#   'Cidade': 'Uberlândia',
#   'Descrição': 'Importante polo econômico e cultural, com parques e eventos.',
#   'Quantidade de Pontos Turísticos': '10+',
#   'Latitude': -18.9136,
#   'Longitude': -48.275},
#  {'_id': ObjectId('65567f28c38f4a4b71f9f3db'),
#   'Cidade': 'São Thomé das Letras',
#   'Descrição': 'Cidade mística com paisagens naturais e lendas locais.',
#   'Quantidade de Pontos Turísticos': '10+',
#   'Latitude': -21.7215,
#   'Longitude': -44.9825},
#  {'_id': ObjectId('65567f28c38f4a4b71f9f3dc'),
#   'Cidade': 'Sete Lagoas',
#   'Descrição': 'Oferece atrações históricas, parques e uma barragem imponente.',
#   'Quantidade de Pontos Turísticos': '10+',
#   'Latitude': -19.4656,
#   'Longitude': -44.2469},
#  {'_id': ObjectId('65567f28c38f4a4b71f9f3dd'),
#   'Cidade': 'Nova Lima',
#   'Descrição': 'Próxima a Belo Horizonte, conhecida por suas paisagens e mineração.',
#   'Quantidade de Pontos Turísticos': '10+',
#   'Latitude': -19.9846,
#   'Longitude': -43.8506},
#  {'_id': ObjectId('65567f28c38f4a4b71f9f3de'),
#   'Cidade': 'Lavras',
#   'Descrição': 'Importante centro universitário, com praças e patrimônio histórico.',
#   'Quantidade de Pontos Turísticos': '10+',
#   'Latitude': -21.2425,
#   'Longitude': -45.0002},
#  {'_id': ObjectId('65567f28c38f4a4b71f9f3df'),
#   'Cidade': 'Patos de Minas',
#   'Descrição': 'Destaque regional, com eventos culturais e paisagens naturais.',
#   'Quantidade de Pontos Turísticos': '10+',
#   'Latitude': -18.5766,
#   'Longitude': -46.5193}]

# %%
center_lat = -19.9026404
center_lon = -44.1288636

# %%
consulta = list(pontosTur.find())

# %%
df_convertido = pd.DataFrame(consulta)

# %%
df_convertido.iloc[0]
# Out:
# _id                                                         65567f28c38f4a4b71f9f3cc
# Cidade                                                                    Ouro Preto
# Descrição                          Cidade histórica com arquitetura colonial e di...
# Quantidade de Pontos Turísticos                                                  20+
# Latitude                                                                    -20.3796
# Longitude                                                                   -43.5122
# Name: 0, dtype: object

# %%
locationmap = folium.Map(location=[ center_lat , center_lon ], zoom_start=6, width=800, height=600)

# %%
qtde = len(df_convertido)

# %%
qtde
# Out:
# 20

# %%
for i in range(qtde):
    lng = float(df_convertido.iloc[i]['Longitude'])
    lat = float(df_convertido.iloc[i]['Latitude'])
    description = 'Nome: ' +str(df_convertido.iloc[i]['Cidade'])+ '<br> Descrição: ' +str(df_convertido.iloc[i]['Descrição'])
    folium.Marker( [ lat , lng ],
                  popup=description,
                   icon=folium.Icon(color='red')).add_to(locationmap)

# %%
locationmap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_39c8fe9bb44edce5d24b6b97c6d70a9c {
#                     position: relative;
#                     width: 800.0px;
#                     height: 600.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_39c8fe9bb44edce5d24b6b97c6d70a9c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_39c8fe9bb44edce5d24b6b97c6d70a9c = L.map(
#                 &quot;map_39c8fe9bb44edce5d24b6b97c6d70a9c&quot;,
#                 {
#                     center: [-19.9026404, -44.1288636],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6cabdecb391bf70d2fc127a45eec3c27 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_39c8fe9bb44edce5d24b6b97c6d70a9c);
#
#
#             var marker_d7435a4ecf6b0e651b6cc925a0f59fa8 = L.marker(
#                 [-20.3796, -43.5122],
#                 {}
#             ).addTo(map_39c8fe9bb44edce5d24b6b97c6d70a9c);
#
#
#             var icon_be959ae32e79811f6665728455ae1b81 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_d7435a4ecf6b0e651b6cc925a0f59fa8.setIcon(icon_be959ae32e79811f6665728455ae1b81);
#
#
#         var popup_6fac4b2cae507ee90cad6c1d2039ff8d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_18d9d557f4129423d7b87d48453007ba = $(`&lt;div id=&quot;html_18d9d557f4129423d7b87d48453007ba&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Nome: Ouro Preto&lt;br&gt; Descrição: Cidade histórica com arquitetura colonial e diversas igrejas barrocas.&lt;/div&gt;`)[0];
#                 popup_6fac4b2cae507ee90cad6c1d2039ff8d.setContent(html_18d9d557f4129423d7b87d48453007ba);
#
#
#
#         marker_d7435a4ecf6b0e651b6cc925a0f59fa8.bindPopup(popup_6fac4b2cae507ee90cad6c1d2039ff8d)
#         ;
#
#
#
#
#             var marker_e3110230b07bd6b952d608b3fd2e6e61 = L.marker(
#                 [-19.919, -43.9386],
#                 {}
#             ).addTo(map_39c8fe9bb44edce5d24b6b97c6d70a9c);
#
#
#             var icon_5f9f607065c5e25381a77c023300c4e3 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_e3110230b07bd6b952d608b3fd2e6e61.setIcon(icon_5f9f607065c5e25381a77c023300c4e3);
#
#
#         var popup_194345019e83bd999f172812fae8d448 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4835053f92dd9c6929383661a36c7e02 = $(`&lt;div id=&quot;html_4835053f92dd9c6929383661a36c7e02&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Nome: Belo Horizonte&lt;br&gt; Descrição: Capital de Minas Gerais, com museus, parques e arquitetura moderna.&lt;/div&gt;`)[0];
#                 popup_194345019e83bd999f172812fae8d448.setContent(html_4835053f92dd9c6929383661a36c7e02);
#
#
#
#         marker_e3110230b07bd6b952d608b3fd2e6e61.bindPopup(popup_194345019e83bd999f172812fae8d448)
#         ;
#
#
#
#
#             var marker_abd28e8ce77e1a64a2ab21a3b608dfbf = L.marker(
#                 [-20.3778, -43.414],
#                 {}
#             ).addTo(map_39c8fe9bb44edce5d24b6b97c6d70a9c);
#
#
#             var icon_ce9109c1696e385c9a76f1b24c4accc4 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_abd28e8ce77e1a64a2ab21a3b608dfbf.setIcon(icon_ce9109c1696e385c9a76f1b24c4accc4);
#
#
#         var popup_f1f31d9fde56752ccefcf7f84f812b3c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_59cd884bb303f952bac69f4b45114f25 = $(`&lt;div id=&quot;html_59cd884bb303f952bac69f4b45114f25&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Nome: Mariana&lt;br&gt; Descrição: Cidade próxima a Ouro Preto, também com arquitetura colonial e museus.&lt;/div&gt;`)[0];
#                 popup_f1f31d9fde56752ccefcf7f84f812b3c.setContent(html_59cd884bb303f952bac69f4b45114f25);
#
#
#
#         marker_abd28e8ce77e1a64a2ab21a3b608dfbf.bindPopup(popup_f1f31d9fde56752ccefcf7f84f812b3c)
#         ;
#
#
#
#
#             var marker_b0a146b80a7142fde5b731eadb026c15 = L.marker(
#                 [-21.1106, -
